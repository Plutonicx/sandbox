# %%
import numpy as np
import pandas as pd

# %%
from PIL import Image, ImageFilter, ImageEnhance

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files (x86)/Tesseract-OCR/tesseract'

# %%
im = Image.open("remind-app.jpg") # the second one

# %%
print(pytesseract.image_to_string(Image.open('sample_text.jpg'), config='letters'))
# Out:
# sqmpb wxf klere
#
# 123456
#
# xzw2
#
# kleuo world

# %%
im = im.filter(ImageFilter.MedianFilter())
enhancer = ImageEnhance.Contrast(im)
im = enhancer.enhance(2)
im = im.convert('1')
im.save('temp2.jpg')
text = pytesseract.image_to_string(Image.open('temp2.jpg'))
print(text)
# Out:
# CLASSES I OWN
#
# 0 Italian Practice
#
# Arts and Crafts
#
#
#
# Geometry
# CLASSES Iâ€˜VE JOINEO
# 0 Rocket Science
#
# Â® Statistics
#
# % Pickup Basketball

# %%
text
# Out:
# 'CLASSES I OWN\n\n0 Italian Practice\n\nArts and Crafts\n\n \n\nGeometry\nCLASSES Iâ€˜VE JOINEO\n0 Rocket Science\n\nÂ® Statistics\n\n% Pickup Basketball'

# %% [markdown]
# # see https://github.com/tesseract-ocr/tesseract/wiki/Command-Line-Usage for more details

# %% [markdown]
# # to get coords - use command line interface and read tsv file

# %%
from subprocess import call

# %%
call('"C:/Program Files (x86)/Tesseract-OCR/tesseract.exe" remindapp.jpg remindapp_eng tsv')
# Out:
# 0

# %%
text_data = pd.read_csv('remindapp_eng.tsv', delimiter='\\t')
# Out:
# C:\Users\Stoja\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
text_data['text'] = text_data['text'].apply(lambda x: str(x))

# %%
text_data[text_data['text'] != 'None']
# Out:
#     level  page_num  block_num  par_num  line_num  word_num  left   top  \
# 4       5         1          1        1         1         1   115    94
# 8       5         1          2        1         1         1   216   225
# 9       5         1          2        1         1         2   307   225
# 10      5         1          2        1         1         3   438   226
# 22      5         1          5        1         1         1   194   724
# 23      5         1          5        1         1         2   274   724
# 25      5         1          5        1         2         1   193   757
# 29      5         1          6        1         1         1   192   821
# 30      5         1          6        1         1         2   249   821
# 31      5         1          6        1         1         3   304   821
# 35      5         1          7        1         1         1   193   854
# 36      5         1          7        1         1         2   219   854
# ...

# %% [markdown]
# # Trying another file using additional commands

# %%
call('"C:/Program Files (x86)/Tesseract-OCR/tesseract.exe" sample_text.jpg sample_text_eng --oem 2 eng tsv')
# Out:
# 0

# %%
sample_text = pd.read_csv('sample_text_eng.tsv', delimiter='\\t')
# Out:
# C:\Users\Stoja\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
sample_text
# Out:
#     level  page_num  block_num  par_num  line_num  word_num  left  top  width  \
# 0       1         1          0        0         0         0     0    0    392
# 1       2         1          1        0         0         0    23   28    199
# 2       3         1          1        1         0         0    23   28    199
# 3       4         1          1        1         1         0    23   28    199
# 4       5         1          1        1         1         1    23   28     85
# 5       5         1          1        1         1         2   117   28     44
# 6       5         1          1        1         1         3   171   28     51
# 7       2         1          2        0         0         0   124  196     75
# 8       3         1          2        1         0         0   124  196     75
# 9       4         1          2        1         1         0   124  196     75
# 10      5         1          2        1         1         1   124  196     75
# ...
